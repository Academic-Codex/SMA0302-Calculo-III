# %% [markdown]
# Aula 01

# %%
from IPython.display import HTML

HTML("""
<style>
div.input_zone {
    display: none;
}


body {
    background-color: #fff6fb;
}

.rendered_html {
    font-size: 16px;
    line-height: 1.55;
}

.CodeMirror {
    background: #1f1f24;
    color: white;
}

</style>
""")
# Out:
# <style>
# div.input_zone {
#     display: none;
# }
#
#
# body {
#     background-color: #fff6fb;
# }
#
# .rendered_html {
#     font-size: 16px;
#     line-height: 1.55;
# }
#
# .CodeMirror {
#     background: #1f1f24;
#     color: white;
# }
#
# </style>
